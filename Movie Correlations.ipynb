# %%
#importing all the reqquired libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
#reading the data

df = pd.read_csv(r'/Users/aryan/Downloads/movies.csv')
pd.set_option('display.max_columns', None)

# %%
#quick look at the data

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# now we will look if there is missing data in it


for col in df.columns:
    percentage_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col,percentage_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
df.isna().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
# now we will remove nulls from gross and budget col
df = df.dropna(subset = ['budget','gross'])
df.isna().sum()
# Out:
# name         0
# rating      12
# genre        0
# year         0
# released     0
# score        0
# votes        0
# director     0
# writer       0
# star         0
# country      1
# budget       0
# gross        0
# company      2
# runtime      1
# dtype: int64

# %%
# we will look at data types of our cols

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#there is no need for decimal in "budget" and "gross" col. so we should change its datatype

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
#right now the year col is incorrect. so we will create year_correct col. since the year is in between,
#we will use regex

df['year_correct'] = df['released'].astype(str).str.extract(r'(\d{4})')
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
#now we will order it by highest grossing

df = df.sort_values(by = 'gross',inplace = False, ascending = False)

# %%
# we will look at distinct values
pd.set_option('display.max_rows',None)
df['company'].drop_duplicates().sort_values(ascending = False).head(40)
# Out:
# 7129                                thefyzz
# 5664                            micro_scope
# 4007                               i5 Films
# 6793                             i am OTHER
# 6420                                   erbp
# 3776                         double A Films
# 3330            Zucker Brothers Productions
# 520                        Zoetrope Studios
# 2213                     Zeta Entertainment
# 3698                Zentropa Entertainments
# 1180                   Zenith Entertainment
# 5180                        Zazen Produções
# 1321               Zanuck/Brown Productions
# 1329            Zacharias-Buhai Productions
# 789               Young Sung Production Co.
# 5125             Young Hannibal Productions
# 5499                            Yellow Bird
# 4618                         Yash Raj Films
# 4990              Yari Film Group Releasing
# 5410                  Yari Film Group (YFG)
# 5583                  X-Filme Creative Pool
# ...

# %%
# now we will look at cols that have high correlations (ex: high buget -> high gross)
# we will use a scatter plot for it


plt.scatter(x = df['budget'] , y = df['gross'])

plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show()

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# now we will plot budget vs gross using seaborn . 

sns.regplot(x = 'budget' , y = 'gross', data = df, scatter_kws = {"color" : "red"}, line_kws = {"color":"blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# now we will look at actual correlation

df.corr(numeric_only = True, method = 'pearson')

# there are diff types/methods of corr. by deafult = pearson. other methods : kendall, spearman, etc
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.055174  0.205758  0.327781  0.274264  0.074203
# score    0.055174  1.000000  0.473809  0.071792  0.222143  0.414580
# votes    0.205758  0.473809  1.000000  0.440021  0.614904  0.352437
# budget   0.327781  0.071792  0.440021  1.000000  0.740395  0.318595
# gross    0.274264  0.222143  0.614904  0.740395  1.000000  0.275596
# runtime  0.074203  0.414580  0.352437  0.318595  0.275596  1.000000

# %%
#there is high correlation bw budget and gross

# %%
# this is difficult to visualize. we will use a heatmap

correlation_matrix = df.corr(numeric_only = True, method = 'pearson')
sns.heatmap(correlation_matrix, annot = True )


plt.title('Correlation Between Numeric Columns')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
# now we will look at comapny again
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# we can assign a numeric val to each company and then use that val to determine the correlation
# we will look for cols that are string and we convert them to category data type
# then we will use .cat.codes, which will automatically assign the suitable numeric values to the col values

df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes

df_numerized.head(20)
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   387       5      0  2009       528    7.8  1100000.0       787    1265
# 7445   389       5      0  2019       138    8.4   903000.0       106     515
# 3045  4923       5      6  1997       535    7.8  1100000.0       787    1265
# 6663  3656       5      0  2015       530    7.8   876000.0       770    1810
# 7244   390       5      0  2018       146    8.4   897000.0       106     515
# 7480  4402       4      2  2019      1130    6.9   222000.0      1014    1364
# 6653  2125       5      0  2015      1307    7.0   593000.0       337    2530
# 6043  3891       5      0  2012      1905    8.0  1300000.0      1062    1650
# 6646  1545       5      0  2015       166    7.1   370000.0       811     483
# 7494  1534       4      2  2019      2059    6.8   148000.0       279    1386
# 6644   388       5      0  2015      1717    7.3   777000.0      1062    1650
# ...

# %%
#looking at original df again just for comparison
df.head(20)
# Out:
#                                               name rating      genre  year  \
# 5445                                        Avatar  PG-13     Action  2009
# 7445                             Avengers: Endgame  PG-13     Action  2019
# 3045                                       Titanic  PG-13      Drama  1997
# 6663    Star Wars: Episode VII - The Force Awakens  PG-13     Action  2015
# 7244                        Avengers: Infinity War  PG-13     Action  2018
# 7480                                 The Lion King     PG  Animation  2019
# 6653                                Jurassic World  PG-13     Action  2015
# 6043                                  The Avengers  PG-13     Action  2012
# 6646                                     Furious 7  PG-13     Action  2015
# 7494                                     Frozen II     PG  Animation  2019
# 6644                       Avengers: Age of Ultron  PG-13     Action  2015
# ...

# %%
#now we make another correlation matrix


corr_matrix2 = df_numerized.corr(numeric_only = True, method = 'pearson')

sns.heatmap(corr_matrix2,annot = True)

plt.title('Correlation between all cols')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
df_numerized.corr()
# Out:
#                   name    rating     genre      year  released     score  \
# name          1.000000 -0.023013  0.009617  0.024435 -0.005896  0.014955
# rating       -0.023013  1.000000  0.128102  0.022668  0.018836  0.059550
# genre         0.009617  0.128102  1.000000 -0.073026  0.021712  0.034061
# year          0.024435  0.022668 -0.073026  1.000000 -0.001481  0.055174
# released     -0.005896  0.018836  0.021712 -0.001481  1.000000  0.046424
# score         0.014955  0.059550  0.034061  0.055174  0.046424  1.000000
# votes         0.012915  0.009255 -0.136457  0.205758  0.029029  0.473809
# director      0.013699  0.014847 -0.009303 -0.036936  0.003341  0.005573
# writer        0.011602 -0.006923  0.017500 -0.024568  0.008514  0.012860
# star         -0.007109  0.003737  0.002619 -0.032770  0.015363  0.009121
# country      -0.024555  0.020148 -0.010847 -0.066662 -0.017231 -0.044690
# budget        0.023698 -0.186892 -0.368900  0.327781  0.019888  0.071792
# ...

# %%
#still this is hard to figure out. so we will use unstackig and sorting

# %%
corr_mat3 = df_numerized.corr()

corr_pairs = corr_mat3.unstack()

corr_pairs.head(20)
# Out:
# name    name            1.000000
#         rating         -0.023013
#         genre           0.009617
#         year            0.024435
#         released       -0.005896
#         score           0.014955
#         votes           0.012915
#         director        0.013699
#         writer          0.011602
#         star           -0.007109
#         country        -0.024555
#         budget          0.023698
#         gross           0.005966
#         company         0.021209
#         runtime         0.010800
#         year_correct    0.024734
# rating  name           -0.023013
#         rating          1.000000
#         genre           0.128102
#         year            0.022668
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs.head(20)
# Out:
# budget        genre          -0.368900
# genre         budget         -0.368900
#               gross          -0.244380
# gross         genre          -0.244380
# rating        budget         -0.186892
# budget        rating         -0.186892
# rating        gross          -0.168814
# gross         rating         -0.168814
# votes         genre          -0.136457
# genre         votes          -0.136457
# company       rating         -0.082189
# rating        company        -0.082189
# country       year_correct   -0.073732
# year_correct  country        -0.073732
# company       genre          -0.073293
# genre         company        -0.073293
# year          genre          -0.073026
# genre         year           -0.073026
#               year_correct   -0.068848
# year_correct  genre          -0.068848
# dtype: float64

# %%
#now we can filter out high corr

high_corr = sorted_pairs[(sorted_pairs) > 0.5]

high_corr.head(20)
# Out:
# gross         votes           0.614904
# votes         gross           0.614904
# gross         budget          0.740395
# budget        gross           0.740395
# year          year_correct    0.998641
# year_correct  year            0.998641
# name          name            1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# writer        writer          1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# dtype: float64

# %%
# we can also see that votes and gross are highly correalted

# therefore, we have figured out that company has low correlation
